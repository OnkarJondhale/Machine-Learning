# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/HP/Downloads/mobiles1.csv')
df
# Out:
#                      battery                                     camera  \
# 0           5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4           4000 mAh Battery              13MP + 2MP | 5MP Front Camera
# ..                       ...                                        ...
# 979         2000 mAh Battery         5MP Rear Camera | 2MP Front Camera
# 980  2680 mAh Li-Ion Battery        13MP Rear Camera | 5MP Front Camera
# 981         4550 mAh Battery             13MP + 5MP | 20MP Front Camera
# 982  2100 mAh Li-Ion Battery         8MP Rear Camera | 2MP Front Camera
# 983         3000 mAh Battery        12MP Rear Camera | 8MP Front Camera
#
#                                   display  \
# 0         15.8 cm (6.22 inch) HD+ Display
# ...

# %%
df.head()
# Out:
#             battery                                     camera  \
# 0  5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4  4000 mAh Battery              13MP + 2MP | 5MP Front Camera
#
#                             display  \
# 0   15.8 cm (6.22 inch) HD+ Display
# 1  16.56 cm (6.52 inch) HD+ Display
# 2  16.56 cm (6.52 inch) HD+ Display
# 3  16.56 cm (6.52 inch) HD+ Display
# 4   15.49 cm (6.1 inch) HD+ Display
#
#                                           memory  \
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 1                           4 GB RAM | 64 GB ROM
# 2                          4 GB RAM | 128 GB ROM
# 3                          4 GB RAM | 128 GB ROM
# 4  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB
#
#                                name  price  \
# ...

# %%
df.tail()
# Out:
#                      battery                               camera  \
# 979         2000 mAh Battery   5MP Rear Camera | 2MP Front Camera
# 980  2680 mAh Li-Ion Battery  13MP Rear Camera | 5MP Front Camera
# 981         4550 mAh Battery       13MP + 5MP | 20MP Front Camera
# 982  2100 mAh Li-Ion Battery   8MP Rear Camera | 2MP Front Camera
# 983         3000 mAh Battery  12MP Rear Camera | 8MP Front Camera
#
#                                   display  \
# 979        12.7 cm (5 inch) FWVGA Display
# 980   13.21 cm (5.2 inch) Full HD Display
# 981     15.24 cm (6 inch) Full HD Display
# 982           12.7 cm (5 inch) HD Display
# 983  14.73 cm (5.8 inch) Quad HD+ Display
#
#                                              memory  \
# 979     1 GB RAM | 8 GB ROM | Expandable Upto 32 MB
# 980                            3 GB RAM | 32 GB ROM
# 981   4 GB RAM | 64 GB ROM | Expandable Upto 256 GB
# 982     1 GB RAM | 8 GB ROM | Expandable Upto 32 GB
# ...

# %%
df.describe()
# Out:
#                price      rating
# count     984.000000  971.000000
# mean    15429.848577    4.241195
# std     12891.355967    0.300296
# min       887.000000    2.700000
# 25%      7499.000000    4.100000
# 50%     11649.000000    4.300000
# 75%     17999.250000    4.400000
# max    104999.000000    4.900000

# %%
df.shape
# Out:
# (984, 10)

# %%
df.isna().sum()
# Out:
# battery        0
# camera         0
# display        0
# memory         0
# name           0
# price          0
# processor      1
# rating        13
# reviews       13
# warranty     148
# dtype: int64

# %%
df[df['processor'].isna()]
# Out:
#               battery            camera                       display  \
# 825  5000 mAh Battery  16MP Rear Camera  16.59 cm (6.53 inch) Display
#
#                    memory                            name  price processor  \
# 825  6 GB RAM | 64 GB ROM  Vivo U20 (Racing Black, 64 GB)  11998       NaN
#
#      rating     reviews warranty
# 825     4.1  33 Reviews      NaN

# %%
df.dropna(subset=['processor'],inplace=True)

# %%
df['processor'].isna().sum()
# Out:
# 0

# %%
df[df['rating'].isna()]
# Out:
#                           battery                                   camera  \
# 356              5020 mAh Battery                         48MP Rear Camera
# 443  4500 mAh Lithium-ion Battery  108MP + 12MP + 12MP | 10MP Front Camera
# 502  4500 mAh Lithium-ion Battery  108MP + 12MP + 12MP | 10MP Front Camera
# 503  4300 mAh Lithium-ion Battery   64MP + 12MP + 12MP | 10MP Front Camera
# 623              3500 mAh Battery                         16MP Rear Camera
# 649              3765 mAh Battery                         48MP Rear Camera
# 664              5020 mAh Battery                         48MP Rear Camera
# 665              5020 mAh Battery                         48MP Rear Camera
# 666              5020 mAh Battery                         48MP Rear Camera
# 750              3500 mAh Battery                         16MP Rear Camera
# 827              3500 mAh Battery                         16MP Rear Camera
# ...

# %%
print(df['rating'].mean())
df['rating'] = df['rating'].fillna(df['rating'].mean())
# Out:
# 4.241340206185567

# %%
df['rating'].isna().sum()
# Out:
# 0

# %%
df[df['warranty'].isna()]
# Out:
#                      battery                                camera  \
# 229         4000 mAh Battery        48MP + 8MP | 13MP Front Camera
# 232         4000 mAh Battery        48MP + 8MP | 13MP Front Camera
# 239         4000 mAh Battery  48MP Rear Camera | 13MP Front Camera
# 247         4000 mAh Battery        48MP + 8MP | 13MP Front Camera
# 248         4000 mAh Battery        48MP + 8MP | 13MP Front Camera
# ..                       ...                                   ...
# 962  1750 mAh Li-Ion Battery  5MP Rear Camera | 0.3MP Front Camera
# 966         2350 mAh Battery   13MP Rear Camera | 5MP Front Camera
# 968         5000 mAh Battery                       5MP Rear Camera
# 969  1750 mAh Li-Ion Battery  5MP Rear Camera | 0.3MP Front Camera
# 979         2000 mAh Battery    5MP Rear Camera | 2MP Front Camera
#
#                                  display  \
# 229  16.0 cm (6.3 inch) Full HD+ Display
# 232  16.0 cm (6.3 inch) Full HD+ Display
# ...

# %%
modeWarranty = df['warranty'].mode()[0]
modeFreq = df['warranty'].value_counts()[modeWarranty]
print("Warranty :",modeWarranty)
print("Frequency :",modeFreq)
# Out:
# Warranty : Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories
# Frequency : 323

# %%
df['warranty'] = df['warranty'].fillna(modeWarranty)

# %%
df['warranty'].isna().sum()
# Out:
# 0

# %%
df['reviews']
# Out:
# 0      55,078 Reviews
# 1      20,062 Reviews
# 2      20,062 Reviews
# 3      20,062 Reviews
# 4      10,091 Reviews
#             ...
# 979       105 Reviews
# 980       516 Reviews
# 981       710 Reviews
# 982        81 Reviews
# 983     2,331 Reviews
# Name: reviews, Length: 983, dtype: object

# %%
df['reviews_numeric'] = df['reviews'].str.split(' ').str[0].str.replace(',','').str.replace('.0','').astype(float)
df['reviews_numeric']
# Out:
# 0      55078.0
# 1      20062.0
# 2      20062.0
# 3      20062.0
# 4      10091.0
#         ...
# 979      105.0
# 980      516.0
# 981      710.0
# 982       81.0
# 983     2331.0
# Name: reviews_numeric, Length: 983, dtype: float64

# %%
df.isna().sum()
# Out:
# battery             0
# camera              0
# display             0
# memory              0
# name                0
# price               0
# processor           0
# rating              0
# reviews            13
# warranty            0
# reviews_numeric    13
# dtype: int64

# %%
df.drop(columns=['reviews'],inplace=True)

# %%
df.keys()
# Out:
# Index(['battery', 'camera', 'display', 'memory', 'name', 'price', 'processor',
#        'rating', 'warranty', 'reviews_numeric'],
#       dtype='object')

# %%
df['reviews_numeric'] = df['reviews_numeric'].fillna(int(df['reviews_numeric'].mean()))
print(int(df['reviews_numeric'].mean()))
# Out:
# 6447

# %%
df.isna().sum()
# Out:
# battery            0
# camera             0
# display            0
# memory             0
# name               0
# price              0
# processor          0
# rating             0
# warranty           0
# reviews_numeric    0
# dtype: int64

# %%
numeric_df = df.select_dtypes(include=['number'])
numeric_df
# Out:
#      price  rating  reviews_numeric
# 0     9999     4.4          55078.0
# 1    10999     4.5          20062.0
# 2    11999     4.5          20062.0
# 3    11999     4.5          20062.0
# 4     7499     4.4          10091.0
# ..     ...     ...              ...
# 979   3590     3.8            105.0
# 980  19999     4.0            516.0
# 981  10499     4.1            710.0
# 982   8990     3.8             81.0
# 983  65900     4.4           2331.0
#
# [983 rows x 3 columns]

# %%
numeric_df.corr()
# Out:
#                     price    rating  reviews_numeric
# price            1.000000  0.433365        -0.113872
# rating           0.433365  1.000000         0.219996
# reviews_numeric -0.113872  0.219996         1.000000

# %%
df
# Out:
#                      battery                                     camera  \
# 0           5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4           4000 mAh Battery              13MP + 2MP | 5MP Front Camera
# ..                       ...                                        ...
# 979         2000 mAh Battery         5MP Rear Camera | 2MP Front Camera
# 980  2680 mAh Li-Ion Battery        13MP Rear Camera | 5MP Front Camera
# 981         4550 mAh Battery             13MP + 5MP | 20MP Front Camera
# 982  2100 mAh Li-Ion Battery         8MP Rear Camera | 2MP Front Camera
# 983         3000 mAh Battery        12MP Rear Camera | 8MP Front Camera
#
#                                   display  \
# 0         15.8 cm (6.22 inch) HD+ Display
# ...

# %%
df['processor'].value_counts()
# Out:
# processor
# Qualcomm Snapdragon 730G Processor                                                                                                                 21
# 1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase    20
# Qualcomm Snapdragon 439 Processor                                                                                                                  18
# MediaTek Helio G90T Processor                                                                                                                      18
# Qualcomm Snapdragon 665 Processor                                                                                                                  18
#                                                                                                                                                    ..
# ...

# %%
df_dummies = pd.get_dummies(df, columns=['battery'], drop_first=True)
df_dummies
# Out:
#                                         camera  \
# 0                12MP + 2MP | 8MP Front Camera
# 1    12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2    12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3    12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4                13MP + 2MP | 5MP Front Camera
# ..                                         ...
# 979         5MP Rear Camera | 2MP Front Camera
# 980        13MP Rear Camera | 5MP Front Camera
# 981             13MP + 5MP | 20MP Front Camera
# 982         8MP Rear Camera | 2MP Front Camera
# 983        12MP Rear Camera | 8MP Front Camera
#
#                                   display  \
# 0         15.8 cm (6.22 inch) HD+ Display
# 1        16.56 cm (6.52 inch) HD+ Display
# 2        16.56 cm (6.52 inch) HD+ Display
# 3        16.56 cm (6.52 inch) HD+ Display
# 4         15.49 cm (6.1 inch) HD+ Display
# ..                                    ...
# 979        12.7 cm (5 inch) FWVGA Display
# 980   13.21 cm (5.2 inch) Full HD Display
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['label_encoded'] = label_encoder.fit_transform(df['processor'])
df
# Out:
#                      battery                                     camera  \
# 0           5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3           5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4           4000 mAh Battery              13MP + 2MP | 5MP Front Camera
# ..                       ...                                        ...
# 979         2000 mAh Battery         5MP Rear Camera | 2MP Front Camera
# 980  2680 mAh Li-Ion Battery        13MP Rear Camera | 5MP Front Camera
# 981         4550 mAh Battery             13MP + 5MP | 20MP Front Camera
# 982  2100 mAh Li-Ion Battery         8MP Rear Camera | 2MP Front Camera
# 983         3000 mAh Battery        12MP Rear Camera | 8MP Front Camera
#
#                                   display  \
# 0         15.8 cm (6.22 inch) HD+ Display
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
plt.plot(df['price'],df['rating'],marker='o')
plt.xlabel('Price')
plt.ylabel('Rating')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.bar(df['memory'],df['price'],color='Skyblue')
plt.xlabel('Memory')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.bar(df['processor'],df['price'],color='Skyblue')
plt.xlabel('Processor')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize=(20, 10))
plt.scatter(df['rating'], df['price'], color='red')
plt.title('Scatter Plot')
plt.xlabel('Rating')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(df['processor'], bins=5, color='purple', edgecolor='black')
plt.title('Histogram')
plt.xlabel('Processor')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns

numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(20, 10))
sns.heatmap(numeric_df, annot=True, cmap='coolwarm', cbar=True)
plt.title('Heatmap')
plt.show()
